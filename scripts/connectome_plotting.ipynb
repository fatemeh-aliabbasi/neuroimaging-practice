# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#defining the dk.csv files location
dkcsv = '/Users/au813606/Documents/MRI_projects/Koras_brain/MRI_analysis/data/subject_redo_new/subject/dicoms/dk.csv'

# %%
# Load connectome matrix
df = pd.read_csv(dkcsv, header=None)

# %%
# Convert to NumPy array
matrix = df.to_numpy()

# %%
# Plot heatmap
plt.figure(figsize=(10,10))
plt.imshow(matrix, vmin=0, vmax=7000, cmap='viridis')

plt.colorbar()

plt.title("Structural Connectome")

plt.show()
